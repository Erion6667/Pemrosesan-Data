# %%
import cv2
import numpy as np
img = cv2.imread("C:/Users/bayuk/OneDrive/Documents/AI/pens/smtr2/Pemrosesan Data/3/bayu1.jpg")
cv2.imshow('bayu', img)
cv2.waitKey()
cv2.imshow('bayu0', img[:,:,0])
cv2.waitKey()
cv2.imshow('bayu1', img[:,:,1])
cv2.waitKey()
cv2.imshow('bayu2', img[:,:,2])
cv2.waitKey()
cv2.destroyAllWindows()
np.savetxt("C:/Users/bayuk/OneDrive/Documents/AI/pens/smtr2/Pemrosesan Data/3/bayu.csv", img.reshape((3, -1)), delimiter=',')

# %%
print('bayu', img) 
cv2.waitKey()
print('bayu0', img[:,:,0])
cv2.waitKey()
print('bayu1', img[:,:,1])
cv2.waitKey()
print('bayu2', img[:,:,2])
cv2.waitKey()
# Out:
# bayu [[[60 60 60]
#   [60 60 60]
#   [60 60 60]
#   ...
#   [26 26 26]
#   [30 30 30]
#   [34 34 34]]
#
#  [[61 61 61]
#   [61 61 61]
#   [61 61 61]
#   ...
#   [24 24 24]
#   [27 27 27]
#   [30 30 30]]
#
#  [[61 61 61]
#   [61 61 61]
#   [61 61 61]
#   ...
#   [22 22 22]
#   [24 24 24]
#   [25 25 25]]
#
#  ...
#
#  [[77 77 77]
#   [77 77 77]
#   [77 77 77]
#   ...
#   [86 86 86]
#   [87 87 87]
#   [88 88 88]]
#
#  [[78 78 78]
#   [78 78 78]
#   [78 78 78]
#   ...
#   [86 86 86]
#   [88 88 88]
#   [89 89 89]]
#
#  [[89 89 89]
#   [89 89 89]
#   [88 88 88]
#   ...
#   [86 86 86]
#   [88 88 88]
#   [90 90 90]]]
# bayu0 [[60 60 60 ... 26 30 34]
#  [61 61 61 ... 24 27 30]
#  [61 61 61 ... 22 24 25]
#  ...
#  [77 77 77 ... 86 87 88]
#  [78 78 78 ... 86 88 89]
#  [89 89 88 ... 86 88 90]]
# bayu1 [[60 60 60 ... 26 30 34]
#  [61 61 61 ... 24 27 30]
#  [61 61 61 ... 22 24 25]
#  ...
#  [77 77 77 ... 86 87 88]
#  [78 78 78 ... 86 88 89]
#  [89 89 88 ... 86 88 90]]
# bayu2 [[60 60 60 ... 26 30 34]
#  [61 61 61 ... 24 27 30]
#  [61 61 61 ... 22 24 25]
#  ...
#  [77 77 77 ... 86 87 88]
#  [78 78 78 ... 86 88 89]
#  [89 89 88 ... 86 88 90]]
# -1

# %%
print(img.shape)
print(img.size)
print(img.dtype)
# Out:
# (480, 480, 3)
# 691200
# uint8

# %%
# Band blue, green dan red masng-masing disimpan pada variabel b,g,r
b, g, r = cv2.split(img)
print(b)
print(g)
print(r)
# Out:
# [[65 65 65 ... 28 32 35]
#  [65 65 65 ... 26 29 32]
#  [66 66 66 ... 24 26 27]
#  ...
#  [73 73 73 ... 65 66 67]
#  [73 73 74 ... 64 65 66]
#  [84 84 84 ... 63 65 67]]
# [[ 64  64  64 ...  28  32  35]
#  [ 64  64  64 ...  26  29  32]
#  [ 65  65  65 ...  24  26  27]
#  ...
#  [ 79  79  79 ...  99 100 101]
#  [ 80  80  79 ... 101 102 103]
#  [ 91  91  89 ... 100 102 104]]
# [[50 50 50 ... 22 26 29]
#  [50 50 50 ... 20 23 26]
#  [51 51 51 ... 18 20 21]
#  ...
#  [74 74 74 ... 68 69 70]
#  [77 77 77 ... 67 70 71]
#  [88 88 87 ... 66 70 72]]

# %%
img=cv2.imread("C:/Users/bayuk/OneDrive/Documents/AI/pens/smtr2/Pemrosesan Data/3/bayu1.jpg")
imageGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("bayu",imageGray)
cv2.waitKey()
# Out:
# 113
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
img=cv2.imread("C:/Users/bayuk/OneDrive/Documents/AI/pens/smtr2/Pemrosesan Data/3/bayu1.jpg")
resize = cv2.resize(img, (200, 200)) # Resize image to 200x200 pixel
cv2.imshow("bayu", resize)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread("C:/Users/bayuk/OneDrive/Documents/AI/pens/smtr2/Pemrosesan Data/3/bayu1.jpg")
resize = cv2.resize(img, (int(img.shape[0]*2), int(img.shape[1]*2))) 
# mengubah ukuran citra menajadi 2x ukuran citra asli
cv2.imshow("bayu", resize)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread("C:/Users/bayuk/OneDrive/Documents/AI/pens/smtr2/Pemrosesan Data/3/bayu1.jpg")
#menyompan hasil modifikasi citra
resize = cv2.resize(img, (int(img.shape[0]*2), int(img.shape[1]*2))) 
# mengubah ukuran citra menajadi 2x ukuran citra asli
cv2.imshow("bayu resize", resize)
cv2.imwrite("bayu_resize.jpg", resize)
 # menyimpan citra baru yang sudah diperbesar 2x
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
img=cv2.imread("C:/Users/bayuk/OneDrive/Documents/AI/pens/smtr2/Pemrosesan Data/3/bayu1.jpg")
cv2.imshow('Hasil Inversi',img)
hasil = 255-img
cv2.imshow('Hasil Inversi',hasil)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# memanggil library yang dibutuhkan
import cv2
import numpy as np
from matplotlib import pyplot as plt
img=cv2.imread("C:/Users/bayuk/OneDrive/Documents/AI/pens/smtr2/Pemrosesan Data/3/bayu1.jpg")
color = ('b','g','r')
for i,col in enumerate(color):
      histr = cv2.calcHist([img],[i],None,[256],[0,256])
      plt.plot(histr,color = col)
      plt.xlim([0,256])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread("C:/Users/bayuk/OneDrive/Documents/AI/pens/smtr2/Pemrosesan Data/3/bayu1.jpg")
hist,bins =np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/cdf.max()
plt.plot(cdf_normalized, color ='b')
plt.hist(img.flatten(),256,[0,256],color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc= 'upper left')
plt.show()
